# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Datset
data=pd.read_csv(r"D:\python.py\DataMinds\Datasets\adult.csv")
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#Display top 10 rows
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
#Display last 10 Rows
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
#Find Shape of dataset (Number of rows and coloumn)
data.shape
# Out:
# (48842, 15)

# %%
#Getting Information about our dataset like total no of rows total no of coloumns datatypes of each coloumn and memory requirements
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#Fetch Random samples from dataset
data.sample(frac=0.50,random_state=100) 
#If you want to quickly explore the dataset,
#you can use a fraction of it to get insights without processing the whole dataset.
# random_state ensures consistency in random processes across different runs of your code.
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 18858   48           Private  207946       HS-grad                9
# 4806    46  Self-emp-not-inc  115971           9th                5
# 36231   41       Federal-gov  356934  Some-college               10
# 73      21           Private  388946  Some-college               10
# 13211   68  Self-emp-not-inc  140892       Masters               14
# ...    ...               ...     ...           ...              ...
# 20665   27           Private  181667       HS-grad                9
# 8101    45  Self-emp-not-inc   40666     Assoc-voc               11
# 21941   56           Private  192869       HS-grad                9
# 8134    30           Private  143078   Prof-school               15
# 26659   26           Private  102420     Bachelors               13
#
#            marital-status         occupation   relationship  \
# 18858            Divorced       Adm-clerical      Unmarried
# ...

# %%
#Check null values
data.isnull().sum()
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Perform Data cleaning

# %%
# Replace ? with NaN
data.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
data["workclass"]=data["workclass"].replace("?",np.nan)
data["occupation"]=data["occupation"].replace("?",np.nan)
data["native-country"]=data["native-country"].replace("?",np.nan)
data.isin(["?"]).sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # Drop all missing value

# %%
#first of all check in percent of missing values
per_missing=data.isnull().sum()*100/len(data)
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
data1=data.dropna(how='any',inplace=False)
# how: Used with dropna() to specify if rows/columns should be dropped based on any or all missing values.
# any: Checks if at least one condition is True in a row or column.

# %%
data.shape
# Out:
# (48842, 15)

# %% [markdown]
# # Check for duplicate data and drop them

# %%
dup=data.duplicated().any()
print("Are there any duplicated value in data",dup)
data=data.drop_duplicates()
# Out:
# Are there any duplicated value in data True

# %%
data.shape
# Out:
# (48842, 15)

# %% [markdown]
# # Get overall Stats about the dataframe

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# # Drop the coloumns eduction_num, capital-gain and capital loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.drop(["educational-num","capital-gain","capital-loss"],axis=1)
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18             ?  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct    Own-child  Black    Male              40
# ...

# %% [markdown]
# # Univariate Analysis
# #we are taking 1 var at a time and perform analysis on it

# %%
# What is the Distributions of Age Coloumn?
#first we are performing on age coloumn
data["age"].describe()
# Out:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data["age"].hist()
# Out:
# <Axes: >

# %%
# Find otal number of persons having age between 17 to 48 (inclusive) using between method
sum((data["age"]>=17) & (data["age"]<=48))
sum(data["age"].between(17,48))
# Out:
# 37321

# %%
#What is the distribtion of workclass column
plt.figure(figsize=(10,10))
data["workclass"].hist()
# Out:
# <Axes: >

# %%
#How many persons have bachelors or masters degree
sum((data["education"]=="Bachelors") | (data["education"]=="Masters"))
sum(data["education"].isin(["Bachelors","Masters"]))
# Out:
# 10682

# %% [markdown]
# # Bivariate Analysis
# #it is used to find relationship between two variables

# %%
sns.boxplot(x='capital-gain',y='age',data=data)
# Out:
# <Axes: xlabel='capital-gain', ylabel='age'>

# %%
# Replace age values [<= 30 and >=20]with 0 and 1
data["age"].value_counts()
plt.figure(figsize=(20,20))
sns.countplot(x="age",data=data)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
data1={'salary':["<=50",">=50",">=50",">=50"]}
data2=pd.DataFrame(data1)
sns.countplot(x="salary",data=data2) 
plt.show()

# %%
def salary_data(sal):
    if sal=="<50":
        return 0
    else:
        return 1

# %%
data2["salary"].apply(salary_data)

#also do with another method
data2["salary"].replace(to_replace=['<=50','>=50'],value=[0,1])
# Out:
# C:\Users\SharrY\AppData\Local\Temp\ipykernel_7360\1559055734.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data2["salary"].replace(to_replace=['<=50','>=50'],value=[0,1])
# 0    0
# 1    1
# 2    1
# 3    1
# Name: salary, dtype: int64

# %%
#Which workclass getting the highest salary?
# basically its for salrty but salry didnt presne t in our dataset
# so we will do for age
data.groupby('workclass')['age'].mean().sort_values(ascending=False)
# Out:
# workclass
# Without-pay         47.285714
# Self-emp-inc        45.799410
# Self-emp-not-inc    45.332470
# Federal-gov         42.577514
# Local-gov           41.676020
# ?                   40.141122
# State-gov           39.512367
# Private             36.903144
# Never-worked        19.900000
# Name: age, dtype: float64
